# %% [markdown]
# <a href="https://colab.research.google.com/github/Upparapallivenkatesh/FMML-ASSESSMENTS-/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 01:12:03--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   219MB/s    in 0.3s
#
# 2024-03-26 01:12:04 (219 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25329  1507.07203v1  We developed a machine vision system to automa...    cs
# 22529  1610.08813v1  This paper proposes a subspace decomposition m...  stat
# 4441   1711.02037v1  Nonnegative matrix factorization (NMF) is a po...  stat
# 27976  1705.02445v1  Human motion modelling is a classical problem ...    cs
# 11580  1606.05642v2  Surprise describes a range of phenomena from u...  stat
# ...             ...                                                ...   ...
# 12793  1703.08378v1  Robot vision is a fundamental device for human...    cs
# 21638   1209.1996v1  We offer a novel view of AdaBoost in a statist...  stat
# 21790  1505.04780v2  We present a unified framework for low-rank ma...  stat
# 21736   1406.1916v1  Nonparametric regression for massive numbers o...  stat
# 1952    1107.4985v1  High dimensional time series are endemic in ap...  stat
#
#                                                    title  year  \
# 25329  Capturing the Dynamics of Pedestrian Traffic U...  2015
# 22529  Sparse Signal Subspace Decomposition Based on ...  2016
# 4441         Randomized Nonnegative Matrix Factorization  2017
# 27976  On human motion prediction using recurrent neu...  2017
# 11580  Balancing New Against Old Information: The Rol...  2016
# ...                                                  ...   ...
# 12793  Feature Fusion using Extended Jaccard Graph an...  2017
# 21638                          A Bayesian Boosting Model  2012
# 21790  Towards Faster Rates and Oracle Property for L...  2015
# 21736                        Compressed Gaussian Process  2014
# 1952      Variational Gaussian Process Dynamical Systems  2011
#
#                                                 keywords
# 25329  [developed, automatically, pedestrians, differ...
# 22529  [decomposition, dictionary, representation, de...
# 4441   [nonnegative, factorization, emergence, challe...
# 27976  [modelling, classical, intersection, applicati...
# 11580  [describes, phenomena, unexpected, behavioral,...
# ...                                                  ...
# 12793  [fundamental, interaction, recognition, inform...
# 21638  [statistical, classification, hierarchically, ...
# 21790  [framework, estimation, nonconvex, penalties, ...
# 21736  [nonparametric, regression, increasingly, impo...
# 1952   [dimensional, applications, computational, exp...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25329    [developed, automatically, pedestrians, differ...
# 22529    [decomposition, dictionary, representation, de...
# 4441     [nonnegative, factorization, emergence, challe...
# 27976    [modelling, classical, intersection, applicati...
# 11580    [describes, phenomena, unexpected, behavioral,...
#                                ...
# 20659    [prioritised, argumentation, representing, arg...
# 6256     [supervised, classifier, dimensionality, decre...
# 17789    [describes, comprehension, commonsense, knowle...
# 12691    [understanding, fundamental, representation, d...
# 13028    [classification, prediction, widespread, commu...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8851 words.
# Out of those 4580 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e211bff6-7d3a-4f37-a120-5e1e5d1c345a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e211bff6-7d3a-4f37-a120-5e1e5d1c345a")) {                    Plotly.newPlot(                        "e211bff6-7d3a-4f37-a120-5e1e5d1c345a",                        [{"x":["projected","different","characteristics","considering","acceleration","pedestrians","capturing","sequences","respective","developed","displayed","superimposed","automatically","dimensional","pedestrian","perspective","scenarios","quantified","processes","approximated","kinematics","adequately","preserves","characteristic","intrinsic","performances","component","knowledge","framework","representation","operation","occurrence","demonstrates","criterion","parameters","dictionary","dependent","regularity","suppressing","distributions","retrieval","frequency","denoising","preserving","decomposition","synthetic","applications","challenged","emergence","factorization","hierarchical","randomized","efficient","evaluated","attaining","measurement","nonnegative","algorithms","alternating","fundamental","deterministic","algorithm","substantial","dimension","prediction","procedures","intersection","modelling","architecture","synthesis","architectures","representations","augmented","evaluation","performance","investigate","functions","surprisingly","typically","approaches","methodologies","classical","literature","following","recurrent","interaction","encountering","eventually","undergoes","surprising","responses","phenomena","describes","minimizing","likelihood","unexpected","behavioral","environment","environments","distribution","commitment","dynamically","exploration","statistics","information","balancing","interpretation","classification","optimized","naturally","predictive","magnitudes","interpretable","convolutional","resulting","outperform","interpreting","interpret","particular","regression","understanding","derivatives","processing","exemplify","considerably","successful","implementation","smoothness","understood","important","automatic","reduction","empirical","tempering","importance","quadrature","considered","sequential","demonstrate","investigation","magnitude","sensitive","integration","determined","practical","numerical","robustness","confusion","conducted","furthermore","theoretically","perceptron","introduce","contributions","evidenced","classifiers","generalization","characterize","simulations","aforementioned","extension","multiclass","translation","inference","specification","boilerplate","utilities","submissions","multimodal","decouples","essential","autonomous","generalize","annotated","effectiveness","baselines","featuring","occupancy","companies","detections","assistance","transformation","awareness","collected","attitudes","embedding","advertising","predicting","establish","extraction","autoencoders","superiority","structure","heterogeneous","recommendation","mainstream","sentiment","unobserved","experimental","summarizes"],"y":[13,726,90,72,14,8,50,105,10,198,6,3,183,184,19,64,95,12,107,17,3,9,14,34,38,39,109,356,520,391,41,23,57,47,242,45,65,5,3,124,103,58,39,44,73,121,440,9,14,33,112,27,406,124,3,31,8,610,33,93,35,780,48,62,222,42,14,49,235,41,122,248,34,240,913,142,211,30,121,456,19,89,113,85,142,83,2,11,3,12,36,35,97,43,70,5,10,111,94,227,3,32,54,73,678,16,43,489,47,55,65,6,34,401,144,110,10,16,266,129,161,7,306,3,21,67,135,14,34,375,168,92,135,1,82,1,114,65,566,27,56,45,43,30,144,82,95,5,75,160,47,21,360,50,3,103,114,45,46,7,84,8,117,222,19,1,4,2,32,1,68,55,62,71,203,65,4,6,14,15,12,60,9,69,1,113,9,81,53,126,21,32,327,33,24,5,44,3,389,5],"type":"bar"},{"x":["projected","different","characteristics","considering","acceleration","pedestrians","capturi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4580,), (4580, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8066666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilities</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>Causation</span> <span style=''>Bounds</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3058823529411764);'>Identification</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>deals</span> <span style=''>with</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3047619047619048);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>that</span> <span style=''>one</span> <span style=''>event</span> <span style=''>was</span> <span style=''>a</span> <span style=''>cause</span> <span style=''>of</span> <span style=''>another</span> <span style=''>in</span> <span style=''>a</span> <span style=''>given</span> <span style=''>scenario</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>semantical</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>definitions</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4529914529914531);'>necessary</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>causation</span> <span style=''>(or</span> <span style=''>both)</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimally</span> <span style=''>bound</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3846153846153846);'>quantities</span> <span style=''>from</span> <span style=''>data</span> <span style=''>obtained</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3843416370106762);'>experimental</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5675675675675677);'>observational</span> <span style=''>studies</span> <span style=''>making</span> <span style=''>minimal</span> <span style='background-color:rgba(255, 0, 0, 0.3434343434343434);'>assumptions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>concerning</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generating</span> <span style=''>process</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>strengthen</span> <span style=''>the</span> <span style=''>results</span> <span style=''>of</span> <span style=''>Pearl</span> <span style=''>(1999)</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>weakening</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.5444444444444445);'>generation</span> <span style='background-color:rgba(255, 0, 0, 0.3434343434343434);'>assumptions</span> <span style=''>and</span> <span style=''>deriving</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretically</span> <span style=''>sharp</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>causation</span> <span style=''>These</span> <span style=''>results</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>delineate</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>with</span> <span style=''>Panel</span> <span style=''>Count</span> <span style=''>Data</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modulated</span> <span style=''>Poisson</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>when</span> <span style=''>the</span> <span style=''>temporal</span> <span style=''>data</span> <span style=''>appear</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>panel</span> <span style=''>counts</span> <span style=''>Panel</span> <span style=''>count</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequently</span> <span style=''>arise</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>subjects</span> <span style=''>are</span> <span style=''>observed</span> <span style=''>only</span> <span style=''>at</span> <span style=''>discrete</span> <span style=''>time</span> <span style=''>points</span> <span style=''>and</span> <span style=''>only</span> <span style=''>the</span> <span style=''>numbers</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>occurrences</span> <span style=''>of</span> <span style=''>the</span> <span style=''>events</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subsequent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>times</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>The</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>occurrence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>timestamps</span> <span style=''>of</span> <span style=''>the</span> <span style=''>events</span> <span style=''>are</span> <span style=''>unknown</span> <span style=''>The</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conducting</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modulated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intensity</span> <span style=''>function</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractable</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alleviate</span> <span style=''>the</span> <span style=''>problems</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style=''>evidence</span> <span style=''>lower</span> <span style=''>bound</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>Subspace</span> <span style=''>System</span> <span style='background-color:rgba(0, 255, 0, 0.3058823529411764);'>Identification</span> <span style=''>via</span> <span style=''>Weighted</span> <span style=''>Nuclear</span> <span style=''>Norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>Subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3058823529411764);'>identification</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>and</span> <span style=''>very</span> <span style=''>well</span> <span style=''>studied</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>system</span> <span style='background-color:rgba(0, 255, 0, 0.3058823529411764);'>identification</span> <span style=''>The</span> <span style=''>problem</span> <span style=''>was</span> <span style=''>recently</span> <span style=''>posed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>via</span> <span style=''>the</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.36842105263157904);'>relaxation</span> <span style=''>Inspired</span> <span style=''>by</span> <span style=''>robust</span> <span style=''>PCA</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>outliers</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>takes</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>that</span> <span style=''>trades</span> <span style=''>off</span> <span style=''>fit</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>sparsity</span> <span style=''>As</span> <span style=''>in</span> <span style=''>robust</span> <span style=''>PCA</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>problematic</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style=''>suitable</span> <span style='background-color:rgba(255, 0, 0, 0.37606837606837606);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3558282208588957);'>parameter</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>the</span> <span style=''>space</span> <span style=''>in</span> <span style=''>which</span> <span style=''>a</span> <span style=''>suitable</span> <span style='background-color:rgba(255, 0, 0, 0.3558282208588957);'>parameter</span> <span style=''>should</span> <span style=''>be</span> <span style=''>sought</span> <span style=''>can</span> <span style=''>be</span> <span style=''>limited</span> <span style=''>to</span> <span style=''>a</span> <span style=''>bounded</span> <span style=''>open</span> <span style=''>set</span> <span style=''>of</span> <span style=''>the</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.31343283582089554);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3558282208588957);'>parameter</span> <span style=''>space</span> <span style=''>In</span> <span style=''>practice</span> <span style=''>this</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Does</span> <span style=''>Neural</span> <span style=''>Machine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Translation</span> <span style=''>Benefit</span> <span style=''>from</span> <span style=''>Larger</span> <span style=''>Context</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>machine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>translation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>that</span> <span style=''>models</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surrounding</span> <span style=''>text</span> <span style=''>in</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>the</span> <span style=''>source</span> <span style=''>sentence</span> <span style=''>These</span> <span style=''>models</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>both</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>translation</span> <span style=''>quality</span> <span style=''>and</span> <span style=''>pronoun</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>when</span> <span style=''>trained</span> <span style=''>on</span> <span style=''>small</span> <span style=''>corpora</span> <span style=''>although</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvement</span> <span style=''>largely</span> <span style=''>disappears</span> <span style=''>when</span> <span style=''>trained</span> <span style=''>with</span> <span style=''>a</span> <span style=''>larger</span> <span style=''>corpus</span> <span style=''>We</span> <span style=''>also</span> <span style=''>discover</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>based</span> <span style=''>neural</span> <span style=''>machine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>translation</span> <span style=''>is</span> <span style=''>well</span> <span style=''>suited</span> <span style=''>for</span> <span style=''>pronoun</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>and</span> <span style=''>compares</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>favorably</span> <span style=''>with</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>that</span> <span style=''>were</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifically</span> <span style=''>designed</span> <span style=''>for</span> <span style=''>this</span> <span style=''>task</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06623931623931624)
# 	architecture (0.08368945868945869)
# 	experimental (0.13853276353276353)
# 	processing (0.10897435897435898)
# 	information (0.24145299145299146)
# 	representation (0.13924501424501423)
# 	different (0.25854700854700857)
# 	detection (0.1282051282051282)
# 	recognition (0.13354700854700854)
# 	convolutional (0.14280626780626782)
#
# Some Statistics words are:
# 	variational (0.10793172690763052)
# 	estimation (0.16214859437751003)
# 	stochastic (0.14457831325301204)
# 	variables (0.13654618473895583)
# 	theoretical (0.15411646586345382)
# 	distribution (0.1897590361445783)
# 	algorithm (0.3870481927710843)
# 	dimensional (0.17670682730923695)
# 	inference (0.2073293172690763)
# 	regression (0.17771084337349397)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5afa36d6-093b-4024-b64c-77b4596d56c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5afa36d6-093b-4024-b64c-77b4596d56c5")) {                    Plotly.newPlot(                        "5afa36d6-093b-4024-b64c-77b4596d56c5",                        [{"x":["projected","different","characteristics","considering","acceleration","pedestrians","capturing","sequences","respective","developed","displayed","superimposed","automatically","dimensional","pedestrian","perspective","scenarios","quantified","processes","approximated","kinematics","adequately","preserves","characteristic","intrinsic","performances","component","knowledge","framework","representation","operation","occurrence","demonstrates","criterion","parameters","dictionary","dependent","regularity","suppressing","distributions","retrieval","frequency","denoising","preserving","decomposition","synthetic","applications","challenged","emergence","factorization","hierarchical","randomized","efficient","evaluated","attaining","measurement","nonnegative","algorithms","alternating","fundamental","deterministic","algorithm","substantial","dimension","prediction","procedures","intersection","modelling","architecture","synthesis","architectures","representations","augmented","evaluation","performance","investigate","functions","surprisingly","typically","approaches","methodologies","classical","literature","following","recurrent","interaction","encountering","eventually","undergoes","surprising","responses","phenomena","describes","minimizing","likelihood","unexpected","behavioral","environment","environments","distribution","commitment","dynamically","exploration","statistics","information","balancing","interpretation","classification","optimized","naturally","predictive","magnitudes","interpretable","convolutional","resulting","outperform","interpreting","interpret","particular","regression","understanding","derivatives","processing","exemplify","considerably","successful","implementation","smoothness","understood","important","automatic","reduction","empirical","tempering","importance","quadrature","considered","sequential","demonstrate","investigation","magnitude","sensitive","integration","determined","practical","numerical","robustness","confusion","conducted","furthermore","theoretically","perceptron","introduce","contributions","evidenced","classifiers","generalization","characterize","simulations","aforementioned","extension","multiclass","translation","inference","specification","boilerplate","utilities","submissions","multimodal","decouples","essential","autonomous","generalize","annotated","effectiveness","baselines","featuring","occupancy","companies","detections","assistance","transformation","awareness","collected","attitudes","embedding","advertising","predicting","establish","extraction","autoencoders","superiority","structure","heterogeneous","recommendation","mainstream","sentiment","unobserved","experimental","summarizes","development","conjunction","challenge","promising","solutions","intelligent","competition","construction","assessment","background","especially","classifying","disclosure","nomination","challenges","enhancement","contribution","vulnerabilities","circumvents","identifying","discovery","computationally","structured","simultaneously","employing","bootstrapping","databases","traditional","discussed","facilitate","supervised","contributes","demonstrated","motivates","differently","experiments","supervision","extensive","association","modalities","according","initialized","differentiable","repulsive","maximally","improving","decreases","nonparametric","divergence","particles","iteratively","efficiency","direction","transports","dimensions"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	repulsive
# 	transports
# 	reinterpret
# 	reparametrizations
# 	explainability
# 	tightness
# 	deletions
# 	kontorovich
# 	postulate
# 	resolvable
# 	manageable
# 	psychiatric
# 	consonants
# 	subpopulations
# 	subgradient
# 	criticize
# 	binarycategorical
# 	stragglers
# 	straggler
# 	sparsities
# Some words which never appear in Statistics papers:
# 	superimposed
# 	evidenced
# 	occupancy
# 	transducer
# 	connectionist
# 	transcript
# 	transcribed
# 	transcripts
# 	dialogues
# 	multiparty
# 	evolvable
# 	combinational
# 	reconfigurable
# 	generations
# 	occlusions
# 	deformations
# 	refocusing
# 	checkerboard
# 	fixations
# 	attentional

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0618493570116355e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7558333333333334
